# %%
"""
=========================================================
Project: End-to-End GitHub Streaming Pipeline
Notebook: 00_config / project_config

Description:
Central configuration file used across the project.

Author: Noureddine RIDA
Platform: Databricks Free Edition
=========================================================
"""

# =========================================================
# Unity Catalog
# =========================================================

CATALOG = "de_portfolio"

RAW_SCHEMA = "raw"
BRONZE_SCHEMA = "bronze"
SILVER_SCHEMA = "silver"
GOLD_SCHEMA = "gold"

# =========================================================
# Storage
# =========================================================

RAW_VOLUME_PATH = "/Volumes/de_portfolio/raw/github_volume"

# =========================================================
# GitHub API
# =========================================================

GITHUB_API_URL = "https://api.github.com/events"

# Replace with your own GitHub Personal Access Token
GITHUB_TOKEN = "<YOUR_GITHUB_TOKEN>"

# %%
# %sql
SHOW VOLUMES IN de_portfolio.raw;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>volume_name</th></tr></thead><tbody><tr><td>raw</td><td>github_volume</td></tr></tbody></table></div>
